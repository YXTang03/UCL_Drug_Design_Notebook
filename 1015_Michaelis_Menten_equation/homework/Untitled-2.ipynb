# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']

# %% [markdown]
# intercepts = 0.07641
# slope = 0.02351
# intercepts/slope

# %%
slopes = [4.34748,
5.03376,
5.15664,
8.23278,
16.07182,
42.00241]

inhibitor_conc = [0, 0.03, 0.1, 0.3, 1, 3]
slope, intercept = np.polyfit(inhibitor_conc, slopes, 1)
slope
# Out:
# np.float64(12.521821405302525)

# %%
slope, intercept
# Out:
# (np.float64(12.521821405302525), np.float64(4.228870195751645))

# %%
plt.scatter(inhibitor_conc, slopes, s=18, c='darkred')
a = np.arange(-0.7, 4)
plt.plot(a, slope * a + intercept, c = 'grey')
plt.text(2, 20, f'y = {slope:.2f} x + {intercept:.2f}')
plt.xlabel('[ATP] (mM / L)')
plt.ylabel('Slope')
#ki_slope, ki_intercept = np.polyfit(inhibitor_conc, slopes, 1)
plt.savefig('E:/Coding/jupyter_root/bioinfo_code/1015_Michaelis_Menten_equation/homework/ki.png', dpi=600)

# %%
ki = intercept/slope
f'{ki:.2f}'
# Out:
# '0.34'
