# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame(
    {
        'mor': ['morphine', 'buprenorphine', '5', '7', '19', '30'],
        'gp_potency':[7.4, 8.7, 6.6, 6.4, 7.8, 8.1],
        'gp_efficacy':[100, 55, 96, 104, 95, 84], 
        'b_potency':[6.3, 0, 5.2, 5.1, 6.6, 7.3], 
        'b_efficacy':[100, 0, 55, 56, 15, 15]
    }
)
df
# Out:
#              mor  gp_potency  gp_efficacy  b_potency  b_efficacy
# 0       morphine         7.4          100        6.3         100
# 1  buprenorphine         8.7           55        0.0           0
# 2              5         6.6           96        5.2          55
# 3              7         6.4          104        5.1          56
# 4             19         7.8           95        6.6          15
# 5             30         8.1           84        7.3          15

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 5))
ax[0].plot(df['mor'], df['gp_potency'], marker = 'o', label = 'G-protein')
ax[0].plot(df['mor'], df['b_potency'], marker = 'o', label = r'$\beta$-arrestin')
ax[0].set_ylabel('Potency (pEC50)')

ax[1].plot(df['mor'], df['gp_efficacy'], marker = 'o', label = 'G-protein')
ax[1].plot(df['mor'], df['b_efficacy'], marker = 'o', label = r'$\beta$-arrestin')
ax[1].set_ylabel('Efficacy (%)')

for i in range(len(ax)):
    ax[i].legend()
    ax[i].tick_params(axis='x', labelrotation= 45)
